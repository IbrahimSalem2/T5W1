# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample(8)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 9855   16:53:00   Wednesday              18-30          Male
# 216     7:35:00    Thursday              31-50       Unknown
# 4733   13:00:00      Sunday              18-30          Male
# 11982   2:04:00    Thursday              31-50          Male
# 10520   0:25:00      Sunday              31-50          Male
# 10159  17:41:00      Monday              31-50          Male
# 4514   11:08:00    Thursday              18-30          Male
# 12247  21:25:00    Thursday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 9855    Elementary school                Employee          Below 1yr
# 216    Junior high school                Employee              2-5yr
# 4733   Junior high school                Employee             5-10yr
# 11982   Above high school                Employee              2-5yr
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.dropna(subset=['Defect_of_vehicle'], inplace=True)
df.dropna(subset=['Service_year_of_vehicle'], inplace=True)
df.isnull().sum()
#4000 row approxmitly deleted because it contains null
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               276
# Vehicle_driver_relation         222
# Driving_experience              315
# Type_of_vehicle                 388
# Owner_of_vehicle                 43
# Service_year_of_vehicle           0
# Defect_of_vehicle                 0
# Area_accident_occured            70
# Lanes_or_Medians                 97
# Road_allignment                  27
# Types_of_Junction               430
# Road_surface_type                76
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                86
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                145
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Type_of_vehicle']=df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])
df['Area_accident_occured']=df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0])
df['Lanes_or_Medians']=df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0])
df['Road_allignment']=df['Road_allignment'].fillna(df['Road_allignment'].mode()[0])
df['Types_of_Junction']=df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])
df['Fitness_of_casuality']=df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0])
df['Road_surface_type']=df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0])
df['Vehicle_movement']=df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               276
# Vehicle_driver_relation         222
# Driving_experience              315
# Type_of_vehicle                   0
# Owner_of_vehicle                 43
# Service_year_of_vehicle           0
# Defect_of_vehicle                 0
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction                 0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                86
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Service_year_of_vehicle']=df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0])
df['Type_of_collision']=df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5540 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         5540 non-null   object
#  1   Day_of_week                  5540 non-null   object
#  2   Age_band_of_driver           5540 non-null   object
#  3   Sex_of_driver                5540 non-null   object
#  4   Educational_level            5264 non-null   object
#  5   Vehicle_driver_relation      5318 non-null   object
#  6   Driving_experience           5225 non-null   object
#  7   Type_of_vehicle              5540 non-null   object
#  8   Owner_of_vehicle             5497 non-null   object
#  9   Service_year_of_vehicle      5540 non-null   object
#  10  Defect_of_vehicle            5540 non-null   object
#  11  Area_accident_occured        5540 non-null   object
#  12  Lanes_or_Medians             5540 non-null   object
# ...

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
# Handeld above this text

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.head(20)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# 7   17:20:00      Friday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 10  14:40:00    Saturday              18-30          Male   Above high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
# 18  22:45:00      Monday              18-30          Male  Junior high school
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5540 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         5540 non-null   object
#  1   Day_of_week                  5540 non-null   object
#  2   Age_band_of_driver           5540 non-null   object
#  3   Sex_of_driver                5540 non-null   object
#  4   Educational_level            5264 non-null   object
#  5   Vehicle_driver_relation      5318 non-null   object
#  6   Driving_experience           5225 non-null   object
#  7   Type_of_vehicle              5540 non-null   object
#  8   Owner_of_vehicle             5497 non-null   object
#  9   Service_year_of_vehicle      5540 non-null   object
#  10  Defect_of_vehicle            5540 non-null   object
#  11  Area_accident_occured        5540 non-null   object
#  12  Lanes_or_Medians             5540 non-null   object
# ...

# %%
df['Accident_severity'].value_counts()
one_hot_encoded_df = pd.get_dummies(df['Accident_severity'])

# %%
df['Casualty_class'].value_counts()
# Out:
# Casualty_class
# Driver or rider    2232
# na                 1991
# Pedestrian          761
# Passenger           556
# Name: count, dtype: int64

# %%
df['Service_year_of_vehicle'].value_counts()
# Out:
# Service_year_of_vehicle
# Unknown       2038
# 2-5yrs         954
# Above 10yr     938
# 5-10yrs        767
# 1-2yr          690
# Below 1yr      153
# Name: count, dtype: int64

# %%
org=df.copy()
df.drop(columns=['Service_year_of_vehicle'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5540 entries, 0 to 12315
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         5540 non-null   object
#  1   Day_of_week                  5540 non-null   object
#  2   Age_band_of_driver           5540 non-null   object
#  3   Sex_of_driver                5540 non-null   object
#  4   Educational_level            5264 non-null   object
#  5   Vehicle_driver_relation      5318 non-null   object
#  6   Driving_experience           5225 non-null   object
#  7   Type_of_vehicle              5540 non-null   object
#  8   Owner_of_vehicle             5497 non-null   object
#  9   Defect_of_vehicle            5540 non-null   object
#  10  Area_accident_occured        5540 non-null   object
#  11  Lanes_or_Medians             5540 non-null   object
#  12  Road_allignment              5540 non-null   object
# ...

# %%
dff=org.copy()
dff.drop(columns=['Service_year_of_vehicle'], inplace=True)
dff= dff.replace('na', pd.NA)
dff.dropna(inplace=True)
dff.head(20)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
# 19   8:20:00     Tuesday              18-30          Male  Junior high school
# 21  15:10:00    Thursday              18-30          Male  Junior high school
# 25  18:36:00   Wednesday              18-30          Male  Junior high school
# 26  18:36:00   Wednesday              18-30       Unknown  Junior high school
# 31  18:10:00    Thursday              18-30          Male  Junior high school
# 34  13:57:00    Saturday            Over 51          Male  Junior high school
# 35  13:57:00    Saturday              18-30          Male         High school
# 37  20:30:00      Friday            Over 51          Male  Junior high school
# ...

# %%
org['Age_band_of_casualty'].value_counts()
org['Age_band_of_casualty']=org['Age_band_of_casualty'].replace('18-30', '25')
org['Age_band_of_casualty']=org['Age_band_of_casualty'].replace('31-50', '45')
org['Age_band_of_casualty']=org['Age_band_of_casualty'].replace('Over 51', '55')

# %%
org['Age_band_of_casualty'].value_counts()
org['Age_band_of_casualty']=org['Age_band_of_casualty'].replace('Under 18', '5')

# %%
#Driving_experience
org['Driving_experience'].value_counts()
org['Driving_experience']=org['Driving_experience'].replace('5-10yr', '7')
org['Driving_experience']=org['Driving_experience'].replace('2-5', '3')
org['Driving_experience']=org['Driving_experience'].replace('Above 10yr', '15')
org['Driving_experience']=org['Driving_experience'].replace('2-5', '3')
org['Driving_experience']=org['Driving_experience'].replace('Above 10yr', '15')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5540 entries, 0 to 12315
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         5540 non-null   object
#  1   Day_of_week                  5540 non-null   object
#  2   Age_band_of_driver           5540 non-null   object
#  3   Sex_of_driver                5540 non-null   object
#  4   Educational_level            5264 non-null   object
#  5   Vehicle_driver_relation      5318 non-null   object
#  6   Driving_experience           5225 non-null   object
#  7   Type_of_vehicle              5540 non-null   object
#  8   Owner_of_vehicle             5497 non-null   object
#  9   Defect_of_vehicle            5540 non-null   object
#  10  Area_accident_occured        5540 non-null   object
#  11  Lanes_or_Medians             5540 non-null   object
#  12  Road_allignment              5540 non-null   object
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
org['Age_band_of_driver'].value_counts()
org['Age_band_of_driver']=org['Age_band_of_driver'].replace('18-30', '25')
org['Age_band_of_driver']=org['Age_band_of_driver'].replace('31-50', '45')
org['Age_band_of_driver']=org['Age_band_of_driver'].replace('Over 51', '55')
org['Age_band_of_driver']=org['Age_band_of_driver'].replace('Under 18', '5')

# %%
#Deletinng rows containing Unknown
df = df[df['Sex_of_driver'].str.contains('Unknown')]

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male      5133
# Female     329
# Name: count, dtype: int64

# %%
org['Age_band_of_casualty'].value_counts()
# Out:
# Age_band_of_casualty
# na    1991
# 25    1427
# 45    1123
# 5      584
# 55     415
# Name: count, dtype: int64

# %%
org= org[org['Age_band_of_casualty'].str.contains('na') == False]

# %%
org['Driving_experience']=org['Driving_experience'].replace('2-5yr', '3')
org['Driving_experience']=org['Driving_experience'].replace('1-2yr', '2')
org['Driving_experience']=org['Driving_experience'].replace('Below 1yr', '1')
org['Driving_experience']=org['Driving_experience'].replace('No Licence', '-1')

# %%
org=org= org[org['Driving_experience'].str.contains('unknown') == False]
org['Driving_experience'].value_counts()
# Out:
# Driving_experience
# 7     983
# 3     715
# 15    671
# 2     516
# 1     411
# -1     35
# Name: count, dtype: int64

# %%
org['Driving_experience'].value_counts()
# Out:
# Driving_experience
# 7          983
# 3          715
# 15         671
# 2          516
# 1          411
# -1          35
# unknown      9
# Name: count, dtype: int64

# %%
org.head(50)
# Out:
#          Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8    17:20:00      Friday                 25          Male
# 9    17:20:00      Friday                 25          Male
# 14   17:45:00    Thursday                 45          Male
# 19    8:20:00     Tuesday                 25          Male
# 21   15:10:00    Thursday                 25          Male
# 25   18:36:00   Wednesday                 25          Male
# 26   18:36:00   Wednesday                 25       Unknown
# 31   18:10:00    Thursday                 25          Male
# 32   15:25:00    Thursday                 25          Male
# 34   13:57:00    Saturday                 55          Male
# 35   13:57:00    Saturday                 25          Male
# 37   20:30:00      Friday                 55          Male
# 43    9:12:00   Wednesday                 25          Male
# 47   10:36:00      Friday                 45          Male
# 52   11:38:00    Saturday                 55          Male
# ...

# %%
org['Casualty_severity'] = org['Casualty_severity'].astype(int)
org['Age_band_of_casualty'] = org['Age_band_of_casualty'].astype(int)
org['Driving_experience'] = org['Driving_experience'].astype(int)
org['Age_band_of_driver'] = org['Age_band_of_driver'].astype(int)
# Out:
# Time
# 15:30:00    60
# 11:30:00    58
# 19:00:00    54
# 17:10:00    51
# 17:00:00    48
#             ..
# 19:11:00     1
# 9:42:00      1
# 16:57:00     1
# 13:59:00     1
# 11:44:00     1
# Name: count, Length: 878, dtype: int64

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                          0.0                   0.0
# mean                           NaN                   NaN
# std                            NaN                   NaN
# min                            NaN                   NaN
# 25%                            NaN                   NaN
# 50%                            NaN                   NaN
# 75%                            NaN                   NaN
# max                            NaN                   NaN

# %%
org
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday                 25          Male
# 9      17:20:00      Friday                 25          Male
# 14     17:45:00    Thursday                 45          Male
# 19      8:20:00     Tuesday                 25          Male
# 21     15:10:00    Thursday                 25          Male
# ...         ...         ...                ...           ...
# 12300  19:12:00     Tuesday                 45          Male
# 12303  12:48:00      Friday                 45          Male
# 12305   7:10:00      Friday                 25          Male
# 12313  13:55:00      Sunday                 55          Male
# 12315  13:55:00      Sunday                 25          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee                 15
# 9      Junior high school                Employee                  2
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
